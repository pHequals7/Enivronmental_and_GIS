# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data20 = pd.read_excel('./PM2.5Data.xlsx','Year_2020')
data20.head()
# Out:
#             Date (LT)  Year  Month  Day  Hour  Raw Conc. Conc. Unit
# 0 2020-03-15 00:00:00  2020      3   15     0       27.0      UG/M3
# 1 2020-03-15 01:00:00  2020      3   15     1       27.0      UG/M3
# 2 2020-03-15 02:00:00  2020      3   15     2       25.0      UG/M3
# 3 2020-03-15 03:00:00  2020      3   15     3       30.0      UG/M3
# 4 2020-03-15 04:00:00  2020      3   15     4       26.0      UG/M3

# %%
data20.set_index('Date (LT)',inplace=True)
data20.head()
# Out:
#                      Year  Month  Day  Hour  Raw Conc. Conc. Unit
# Date (LT)
# 2020-03-15 00:00:00  2020      3   15     0       27.0      UG/M3
# 2020-03-15 01:00:00  2020      3   15     1       27.0      UG/M3
# 2020-03-15 02:00:00  2020      3   15     2       25.0      UG/M3
# 2020-03-15 03:00:00  2020      3   15     3       30.0      UG/M3
# 2020-03-15 04:00:00  2020      3   15     4       26.0      UG/M3

# %%
data19 = pd.read_excel('./PM2.5Data.xlsx','Year_2019')
data19.head()
# Out:
#             Date (LT)  Year  Month  Day  Hour  Raw Conc. Conc. Unit
# 0 2019-03-15 00:00:00  2019      3   15     0         32      UG/M3
# 1 2019-03-15 01:00:00  2019      3   15     1         31      UG/M3
# 2 2019-03-15 02:00:00  2019      3   15     2         30      UG/M3
# 3 2019-03-15 03:00:00  2019      3   15     3         35      UG/M3
# 4 2019-03-15 04:00:00  2019      3   15     4         33      UG/M3

# %%
data19.set_index('Date (LT)',inplace=True)
data19.head()
# Out:
#                      Year  Month  Day  Hour  Raw Conc. Conc. Unit
# Date (LT)
# 2019-03-15 00:00:00  2019      3   15     0         32      UG/M3
# 2019-03-15 01:00:00  2019      3   15     1         31      UG/M3
# 2019-03-15 02:00:00  2019      3   15     2         30      UG/M3
# 2019-03-15 03:00:00  2019      3   15     3         35      UG/M3
# 2019-03-15 04:00:00  2019      3   15     4         33      UG/M3

# %%
davg19 = data19.resample('D', how='mean')
davg20 = data20.resample('D', how='mean')
# davg_NA = davg19.loc[d.index]
# davg_daily = davg_NA.fillna(method='ffill')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   """Entry point for launching an IPython kernel.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()

# %%
davg19['Raw Conc.'].plot(figsize=(15,4))

# %%
davg20['Raw Conc.'].plot(figsize=(15,4))

# %%
data19['Month'] = data19['Month'].astype('str')
data19['Day'] = data19['Day'].astype('str')
data19['Hour'] = data19['Hour'].astype('str')

# %%
data20['Month'] = data20['Month'].astype('str')
data20['Day'] = data20['Day'].astype('str')
data20['Hour'] = data20['Hour'].astype('str')

# %%
data19['cindex'] = data19["Month"]+data19["Day"]+data19["Hour"]
data19.head()
# Out:
#                      Year Month Day Hour  Raw Conc. Conc. Unit cindex
# Date (LT)
# 2019-03-15 00:00:00  2019     3  15    0         32      UG/M3   3150
# 2019-03-15 01:00:00  2019     3  15    1         31      UG/M3   3151
# 2019-03-15 02:00:00  2019     3  15    2         30      UG/M3   3152
# 2019-03-15 03:00:00  2019     3  15    3         35      UG/M3   3153
# 2019-03-15 04:00:00  2019     3  15    4         33      UG/M3   3154

# %%
data20['cindex'] = data20["Month"]+data20["Day"]+data20["Hour"]
data20.head()
# Out:
#                      Year Month Day Hour  Raw Conc. Conc. Unit cindex
# Date (LT)
# 2020-03-15 00:00:00  2020     3  15    0       27.0      UG/M3   3150
# 2020-03-15 01:00:00  2020     3  15    1       27.0      UG/M3   3151
# 2020-03-15 02:00:00  2020     3  15    2       25.0      UG/M3   3152
# 2020-03-15 03:00:00  2020     3  15    3       30.0      UG/M3   3153
# 2020-03-15 04:00:00  2020     3  15    4       26.0      UG/M3   3154

# %%
data19['Raw Conc.'].plot(figsize=(15,4))

# %%
data20['Raw Conc.'].plot(figsize=(15,4))

# %%
X1 = data20['cindex'].tolist()
X2 = data19['cindex'].tolist()
Y1 = data20['Raw Conc.'].tolist()
Y2 = data19['Raw Conc.'].tolist()
fig= plt.figure(figsize=(20,5))
plt.xticks(fontsize=3, rotation=90)
# plt.scatter(X1,Y1,color='y',s=10)
# plt.scatter(X2,Y2,color='g',s=10)
plt.plot(X1,Y1)
plt.plot(X2,Y2)
plt.show()

# %%
data19.describe()
# Out:
#          Year   Raw Conc.
# count   840.0  840.000000
# mean   2019.0   16.900000
# std       0.0   11.515735
# min    2019.0    0.000000
# 25%    2019.0    9.000000
# 50%    2019.0   16.000000
# 75%    2019.0   22.000000
# max    2019.0   87.000000

# %%
data20.describe()
# Out:
#          Year   Raw Conc.
# count   801.0  793.000000
# mean   2020.0   18.087011
# std       0.0    8.774892
# min    2020.0    0.000000
# 25%    2020.0   12.000000
# 50%    2020.0   17.000000
# 75%    2020.0   23.000000
# max    2020.0   53.000000
